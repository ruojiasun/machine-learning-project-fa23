# %%
###################################
## Author : Ruojia Sun, adapted from code by Prof. Ami Gates
###################################

import pandas as pd
import sklearn
import re  
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import matplotlib.pyplot as plt
import os

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC

import seaborn as sn

# %%
text_df = pd.read_csv("NewsHeadlines_vectorized_100.csv")

train_df, test_df = train_test_split(text_df, test_size=0.3)

###############################################
## separate LABELS
#################################################

### TEST ---------------------
## Save labels
TEST_Labels=test_df["Label"]
# print(Test1Labels)

## remove labels
TEST = test_df.drop(["Label"], axis=1)

## TRAIN ----------------------------
## Save labels
t=train_df["Label"]

## remove labels
TRAIN = train_df.drop(["Label"], axis=1)

= train_df
= Train1Labels
= test_df
= Test1Labels

# %%
#############################################
###########  SVM ############################
#############################################

## Linear

# C = 1 (best)
c=1
SVM_Model1=LinearSVC(C=c)
SVM_Model1.fit(TRAIN, TRAIN_Labels)

# print("SVM prediction:\n", SVM_Model1.predict(TEST))
# print("Actual:")
# print(TEST_Labels)
SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model1.predict(TEST))
print(f"\nThe confusion matrix for Linear SVC C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe confusion matrix for Linear SVC C={c} is: {accuracy}")
print()


df_cm = pd.DataFrame(SVM_matrix, index = ['inequality', 'not inequality'],
                  columns = ['inequality', 'not inequality'])

sn.set(font_scale=2)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap= "Blues")
plt.title(f"Linear SVM, C={c}")

# C = 0.1
c=0.1
SVM_Model1=LinearSVC(C=c)
SVM_Model1.fit(TRAIN, TRAIN_Labels)

# print("SVM prediction:\n", SVM_Model1.predict(TEST))
# print("Actual:")
# print(TEST_Labels)
SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model1.predict(TEST))
print(f"\nThe confusion matrix for Linear SVC C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe confusion matrix for Linear SVC C={c} is: {accuracy}")
print()

# C = 10
c=10
SVM_Model1=LinearSVC(C=c)
SVM_Model1.fit(TRAIN, TRAIN_Labels)

# print("SVM prediction:\n", SVM_Model1.predict(TEST))
# print("Actual:")
# print(TEST_Labels)
SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model1.predict(TEST))
print(f"\nThe confusion matrix for Linear SVC C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe confusion matrix for Linear SVC C={c} is: {accuracy}")
print()
# Out:
# The confusion matrix for Linear SVC C=1 is:
# [[26  7]
#  [ 5 22]]
#
# The confusion matrix for Linear SVC C=1 is: 0.8
#
#
# The confusion matrix for Linear SVC C=0.1 is:
# [[26  7]
#  [ 6 21]]
#
# The confusion matrix for Linear SVC C=0.1 is: 0.7833333333333333
#
#
# The confusion matrix for Linear SVC C=10 is:
# [[25  8]
#  [ 5 22]]
#
# The confusion matrix for Linear SVC C=10 is: 0.7833333333333333
# c:\Users\sunru\anaconda3\envs\py39\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\sunru\anaconda3\envs\py39\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\sunru\anaconda3\envs\py39\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
## RBF

# C = 200 (best)
c=200
SVM_Model2=sklearn.svm.SVC(C=c, kernel='rbf', 
                           verbose=True, gamma="auto")
SVM_Model2.fit(TRAIN, TRAIN_Labels)

# print("SVM prediction:\n", SVM_Model2.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model2.predict(TEST))
print(f"\nThe confusion matrix for rbf SVM C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM C={c} is: {accuracy}")
print()


df_cm = pd.DataFrame(SVM_matrix, index = ['inequality', 'not inequality'],
                  columns = ['inequality', 'not inequality'])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap= "Blues")
plt.title(f"rbf SVM, C={c}")

# C = 100
c=100
SVM_Model2=sklearn.svm.SVC(C=c, kernel='rbf', 
                           verbose=True, gamma="auto")
SVM_Model2.fit(TRAIN, TRAIN_Labels)

# print("SVM prediction:\n", SVM_Model2.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model2.predict(TEST))
print(f"\nThe confusion matrix for rbf SVM C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM C={c} is: {accuracy}")
print()

# C = 500
c=500
SVM_Model2=sklearn.svm.SVC(C=c, kernel='rbf', 
                           verbose=True, gamma="auto")
SVM_Model2.fit(TRAIN, TRAIN_Labels)

# print("SVM prediction:\n", SVM_Model2.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model2.predict(TEST))
print(f"\nThe confusion matrix for rbf SVM C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM C={c} is: {accuracy}")
print()
# Out:
# [LibSVM]
# The confusion matrix for rbf SVM C=200 is:
# [[27  6]
#  [ 4 23]]
#
# The accuracy for rbf SVM C=200 is: 0.8333333333333334
#
# [LibSVM]
# The confusion matrix for rbf SVM C=100 is:
# [[26  7]
#  [ 4 23]]
#
# The accuracy for rbf SVM C=100 is: 0.8166666666666667
#
# [LibSVM]
# The confusion matrix for rbf SVM C=500 is:
# [[25  8]
#  [ 8 19]]
#
# The accuracy for rbf SVM C=500 is: 0.7333333333333333

# %%
## POLY

d=2
# C = 5000
c= 5000
SVM_Model3=sklearn.svm.SVC(C=c, kernel='poly',degree=d,
                           gamma="auto", verbose=True)

print(SVM_Model3)
SVM_Model3.fit(TRAIN, TRAIN_Labels)
# print("SVM prediction:\n", SVM_Model3.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model3.predict(TEST))
print(f"\nThe confusion matrix for SVM poly d={d}, C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM poly d={d}, C={c} is: {accuracy}")
print()


df_cm = pd.DataFrame(SVM_matrix, index = ['inequality', 'not inequality'],
                  columns = ['inequality', 'not inequality'])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap= "Blues")
plt.title(f"polynomial SVM, d={d}, C={c}")


# C = 1000
c= 1000
SVM_Model3=sklearn.svm.SVC(C=c, kernel='poly',degree=d,
                           gamma="auto", verbose=True)

print(SVM_Model3)
SVM_Model3.fit(TRAIN, TRAIN_Labels)
# print("SVM prediction:\n", SVM_Model3.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model3.predict(TEST))
print(f"\nThe confusion matrix for SVM poly d={d}, C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM poly d={d}, C={c} is: {accuracy}")
print()


# C = 10000
c= 10000
SVM_Model3=sklearn.svm.SVC(C=c, kernel='poly',degree=d,
                           gamma="auto", verbose=True)

print(SVM_Model3)
SVM_Model3.fit(TRAIN, TRAIN_Labels)
# print("SVM prediction:\n", SVM_Model3.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model3.predict(TEST))
print(f"\nThe confusion matrix for SVM poly d={d}, C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM poly d={d}, C={c} is: {accuracy}")
print()
# Out:
# SVC(C=5000, degree=2, gamma='auto', kernel='poly', verbose=True)
# [LibSVM]
# The confusion matrix for SVM poly d=2, C=5000 is:
# [[27  6]
#  [ 5 22]]
#
# The accuracy for rbf SVM poly d=2, C=5000 is: 0.8166666666666667
#
# SVC(C=1000, degree=2, gamma='auto', kernel='poly', verbose=True)
# [LibSVM]
# The confusion matrix for SVM poly d=2, C=1000 is:
# [[30  3]
#  [ 9 18]]
#
# The accuracy for rbf SVM poly d=2, C=1000 is: 0.8
#
# SVC(C=10000, degree=2, gamma='auto', kernel='poly', verbose=True)
# [LibSVM]
# The confusion matrix for SVM poly d=2, C=10000 is:
# [[27  6]
#  [ 6 21]]
#
# The accuracy for rbf SVM poly d=2, C=10000 is: 0.8

# %%
# Polynomial, d=3
d=3

# C = 8500
c= 8500

SVM_Model3=sklearn.svm.SVC(C=c, kernel='poly',degree=d,
                           gamma="auto", verbose=True)

print(SVM_Model3)
SVM_Model3.fit(TRAIN, TRAIN_Labels)
# print("SVM prediction:\n", SVM_Model3.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model3.predict(TEST))
print("\nThe confusion matrix for SVM poly d={d}, C={c}  is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM poly d={d}, C={c} is: {accuracy}")
print()


df_cm = pd.DataFrame(SVM_matrix, index = ['inequality', 'not inequality'],
                  columns = ['inequality', 'not inequality'])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap= "Blues")
plt.title(f"polynomial SVM, d={d}, C={c}")

# C = 7000
c= 7000

SVM_Model3=sklearn.svm.SVC(C=c, kernel='poly',degree=d,
                           gamma="auto", verbose=True)

print(SVM_Model3)
SVM_Model3.fit(TRAIN, TRAIN_Labels)
# print("SVM prediction:\n", SVM_Model3.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model3.predict(TEST))
print("\nThe confusion matrix for SVM poly d={d}, C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM poly d={d}, C={c} is: {accuracy}")
print()



# C = 10000
c= 10000

SVM_Model3=sklearn.svm.SVC(C=c, kernel='poly',degree=d,
                           gamma="auto", verbose=True)

print(SVM_Model3)
SVM_Model3.fit(TRAIN, TRAIN_Labels)
# print("SVM prediction:\n", SVM_Model3.predict(TEST))
# print("Actual:")
# print(TEST_Labels)

SVM_matrix = confusion_matrix(TEST_Labels, SVM_Model3.predict(TEST))
print("\nThe confusion matrix for SVM poly d={d}, C={c} is:")
print(SVM_matrix)
accuracy = (SVM_matrix[0,0]+ SVM_matrix[1,1])/sum(sum(SVM_matrix))
print(f"\nThe accuracy for rbf SVM poly d={d}, C={c} is: {accuracy}")
print()
# Out:
# SVC(C=8500, gamma='auto', kernel='poly', verbose=True)
# [LibSVM]
# The confusion matrix for SVM poly d={d}, C={c}  is:
# [[29  4]
#  [ 8 19]]
#
# The accuracy for rbf SVM poly d=3, C=8500 is: 0.8
#
# SVC(C=7000, gamma='auto', kernel='poly', verbose=True)
# [LibSVM]
# The confusion matrix for SVM poly d={d}, C={c} is:
# [[12 21]
#  [ 1 26]]
#
# The accuracy for rbf SVM poly d=3, C=7000 is: 0.6333333333333333
#
# SVC(C=10000, gamma='auto', kernel='poly', verbose=True)
# [LibSVM]
# The confusion matrix for SVM poly d={d}, C={c} is:
# [[32  1]
#  [14 13]]
#
# The accuracy for rbf SVM poly d=3, C=10000 is: 0.75

# %%
## Credit: https://medium.com/@aneesha/visualising-top-features-in-linear-svm-with-scikit-learn-and-matplotlib-3454ab18a14d
## Define a function to visualize the TOP words (variables)
def plot_coefficients(MODEL=SVM_Model1, COLNAMES=train_df.columns, top_features=15):
    ## Model if SVM MUST be SVC, RE: SVM_Model=LinearSVC(C=10)
    coef = MODEL.coef_.ravel()
    top_positive_coefficients = np.argsort(coef,axis=0)[-top_features:]
    top_negative_coefficients = np.argsort(coef,axis=0)[:top_features]
    top_coefficients = np.hstack([top_negative_coefficients, top_positive_coefficients])
    # create plot
    plt.figure(figsize=(15, 5))
    colors = ["red" if c < 0 else "blue" for c in coef[top_coefficients]]
    plt.bar(  x=  np.arange(2 * top_features)  , height=coef[top_coefficients], width=.5,  color=colors)
    feature_names = np.array(COLNAMES)
    plt.xticks(np.arange(0, (2*top_features)), feature_names[top_coefficients], rotation=60, ha="right")
    plt.show()
    

plot_coefficients()

# %%
points = [[0,1][1,2]]


import matplotlib.pyplot as plt
## Credit: https://medium.com/@aneesha/visualising-top-features-in-linear-svm-with-scikit-learn-and-matplotlib-3454ab18a14d
## Define a function to visualize the TOP words (variables)
def plot_coefficients(MODEL=SVM_Model, COLNAMES=TrainDF1.columns, top_features=10):
    ## Model if SVM MUST be SVC, RE: SVM_Model=LinearSVC(C=10)
    coef = MODEL.coef_.ravel()
    top_positive_coefficients = np.argsort(coef,axis=0)[-top_features:]
    top_negative_coefficients = np.argsort(coef,axis=0)[:top_features]
    top_coefficients = np.hstack([top_negative_coefficients, top_positive_coefficients])
    # create plot
    plt.figure(figsize=(15, 5))
    colors = ["red" if c < 0 else "blue" for c in coef[top_coefficients]]
    plt.bar(  x=  np.arange(2 * top_features)  , height=coef[top_coefficients], width=.5,  color=colors)
    feature_names = np.array(COLNAMES)
    plt.xticks(np.arange(0, (2*top_features)), feature_names[top_coefficients], rotation=60, ha="right")
    plt.show()
    

plot_coefficients()
plt.savefig('KeyWords.pdf')


#########################################################
##  Using the top 2 features from above
## Let's look at the margin of the SVM
##################################################################
from sklearn.svm import SVC
X = np.array([TRAIN["dog"], TRAIN["hike"]])
X = X.transpose()
print(X)
#The classes of the training data
y = TRAIN_Labels
print(y)
from sklearn.preprocessing import LabelBinarizer
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
y=lb.fit_transform(y)

y = np.array(y)
y = y.ravel()  ## to make it the right 1D array type

print(y)


## Here - we need to make y into 0 or 1 so it will plot

#TRAIN
#Define the model with SVC
# Fit SVM with training data
clf = SVC(C=1, kernel="linear")
clf.fit(X, y) 


margin = 2 / np.sqrt(np.sum(clf.coef_ ** 2))

# get the separating hyperplane
#The weights vector w
w = clf.coef_[0]
#print("The weight vector ", w)

#The slope of the SVM sep line
a = -w[0] / w[1]
#print("The slope of the SVM sep line is ", a)

#Create a variable xx that are values between 4 and 8
xx = np.linspace(0, 10)

#Equation of sep line in 2D
# x1  = - b/w1  - (w0/w1 )(x0)
## Note that clf_intercept_[0] is "b"
## Note that a  = -w0/w1 and xx are a bunch of x values
## This is the y values for the main sep line
yy = a * xx - (clf.intercept_[0]) / w[1]

##These plot the two parellel margin lines
# plot the parallel lines to the separating hyperplane 
#that pass through the support vectors and note the margin
#margin = 2 / np.sqrt(np.sum(clf.coef_ ** 2))
#translate the location of the center sep line by
# adding or subtracting a fraaction of the margin 
yy_down = yy + .5*margin
yy_up = yy - .5*margin

# plot the line, the points, and the nearest vectors to the plane
#plt.figure(fignum, figsize=(4, 3))
plt.clf()
plt.plot(xx, yy, 'r-')
plt.plot(xx, yy_down, 'k--')
plt.plot(xx, yy_up, 'k--')

plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=10,
                facecolors='none', zorder=5)
#cmap is the color map
plt.scatter(X[:, 0], X[:, 1], c=y, zorder=5, cmap=plt.cm.Paired)

plt.axis('tight')
